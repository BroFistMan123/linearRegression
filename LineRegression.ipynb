# %%
import matplotlib.pyplot as plt
import numpy as np
from prettytable import PrettyTable
class LinearRegression:

  def __init__(self, data):
    self.data = data
    self.yInt=0
    self.slope=0
    self.mean=()
    
  

  def printGraph(self,datapoint):
    originalPt=self.data
    x_val = [x[0] for x in datapoint]
    y_val = [x[1] for x in datapoint]
    origX=[x[0] for x in originalPt]
    origY=[x[1] for x in originalPt]
    plt.plot(origX,origY,'ob')
    
    plt.plot(x_val,y_val)
    plt.plot(x_val,y_val,'or')
    plt.show()
  def tableFormat(self,dataset):
    t = PrettyTable(['X', 'Y'])
    for i in range(len(dataset)):
      t.add_row([dataset[i][0],dataset[i][1]])
    return t
    
  def getMean(self):
    data=self.data
    xSum=0
    ySum=0
    for i in range(len(data)):
      xSum+=data[i][0]
     
      ySum+=data[i][1]
    xDiv=xSum/len(data)
    yDiv=ySum/len(data)
    
    self.mean=(xDiv,yDiv)

    return self.mean
  def getSlope(self):
    data=self.data
    numerator=0
    denominator=0
    for i in range(len(data)):
      numerator+=(data[i][0]-self.mean[0])*(data[i][1]-self.mean[1])
      denominator+=(data[i][0]-self.mean[0])**2
    self.slope=(numerator/denominator)
    return self.slope
  def getyInt(self):
    b=self.mean[1]-(self.slope*self.mean[0])
    self.yInt=b
    return self.yInt
  def predictValues(self,trainSet):
    predVal=[]
    for i in range(len(trainSet)):
      y=(self.slope*trainSet[i])+self.yInt
      predVal.append((trainSet[i],y))
    
    return predVal
  def runRegression(self):
    print("Given Training Datasets:",self.data)
    print("Mean:", self.getMean())
    print("Slope:",self.getSlope())
    print("Y-Intercept:",self.getyInt())
  def getPercent(self, dataset):
    origY=self.data
    yMean=self.mean
    numerator=0
    denominator=0
    for i in range(len(dataset)):
      numerator+=(origY[i][1]-dataset[i][1])**2
      denominator+=(origY[i][1]-yMean[1])**2
    r=1-(numerator/denominator)
    return r
    

    # return (x,y)
#GENERATING INPUT METHOD
# input_list=[]
# for i in range(100):
#   input_list.append((i,i+3))
# tupleA=tuple(input_list)
  


#DECLARED TUPLE METHOD
tupleA=((1,3),(2,4),(3,2),(4,4),(5,5))
p1=LinearRegression(tupleA)
print(p1.tableFormat(p1.data))
p1.runRegression()
trainingSet=[1,2,3,4,5]
dataset=p1.predictValues(trainingSet)
print("Dataset for Predicted Values: ",dataset)
p1.printGraph(dataset)
p1.getPercent(dataset)
# Out:
# +---+---+
# | X | Y |
# +---+---+
# | 1 | 3 |
# | 2 | 4 |
# | 3 | 2 |
# | 4 | 4 |
# | 5 | 5 |
# +---+---+
# Given Training Datasets: ((1, 3), (2, 4), (3, 2), (4, 4), (5, 5))
# Mean: (3.0, 3.6)
# Slope: 0.4
# Y-Intercept: 2.4
# Dataset for Predicted Values:  [(1, 2.8), (2, 3.2), (3, 3.6), (4, 4.0), (5, 4.4)]
# 0.3076923076923078

# %%
data =  [(1, 2), (2, 4),
 (3, 6), (4,8),
 (5, 10), (6, 12)]
x_val = []
# x_val = [x[0] for x in data]
# y_val = [x[1] for x in data]
y_val = []

for x in data:
  print(x[0])
  x_val.append(x[0])

for x in data:
  print(x[1])
  y_val.append(x[1])
print (x_val)
print (y_val)
plt.plot(x_val,y_val)
plt.plot(x_val,y_val,'or')
plt.show()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 6 ADASDAD
# 2
# 4
# 6
# 8
# 10
# 12
# [1, 2, 3, 4, 5, 6]
# [2, 4, 6, 8, 10, 12]

# %%
from prettytable import PrettyTable
t = PrettyTable(['Name', 'Age'])
t.add_row(['Alice', 24])
t.add_row(['Bob', 19])
print(t)
# Out:
# +-------+-----+
# |  Name | Age |
# +-------+-----+
# | Alice |  24 |
# |  Bob  |  19 |
# +-------+-----+

# %%
#CSV implementation
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("/content/movie_metadata.csv") 
# Preview the first 5 lines of the loaded data 
datasets=[]
# for row in data.itertuples():

  # if row['z']==nan or row['y']==nan or row['x']==nan:
  #   continue
  # print(row)
  # print(row[0],row[1],row[2],row[3])
  # datasets.append((row['x'],row['y'],row['z']))

def getCSV(data,x,y,columnname): 
  datalist={}                 #expects a string param
  xCol=data.columns.get_loc(x)+1
  yCol=data.columns.get_loc(y)+1  #I plus one kay murag sa 1 mag sugod ang table pag update sa itertuple.

  zCol=data.columns.get_loc(columnname)+1
  
  # print("location x: ",xCol,"location y: ",yCol,"location z: ",zCol)
  
  for row in data.itertuples():
    
    datalist.update({row[zCol]:(row[xCol],row[yCol])})
  print(datalist)

data = data.dropna(how='any',axis=0) 
getCSV(data,"gross","budget","movie_title")
# Out:
# {'Avatar\xa0': (760505847.0, 237000000.0), "Pirates of the Caribbean: At World's End\xa0": (309404152.0, 300000000.0), 'Spectre\xa0': (200074175.0, 245000000.0), 'The Dark Knight Rises\xa0': (448130642.0, 250000000.0), 'John Carter\xa0': (73058679.0, 263700000.0), 'Spider-Man 3\xa0': (336530303.0, 258000000.0), 'Tangled\xa0': (200807262.0, 260000000.0), 'Avengers: Age of Ultron\xa0': (458991599.0, 250000000.0), 'Harry Potter and the Half-Blood Prince\xa0': (301956980.0, 250000000.0), 'Batman v Superman: Dawn of Justice\xa0': (330249062.0, 250000000.0), 'Superman Returns\xa0': (200069408.0, 209000000.0), 'Quantum of Solace\xa0': (168368427.0, 200000000.0), "Pirates of the Caribbean: Dead Man's Chest\xa0": (423032628.0, 225000000.0), 'The Lone Ranger\xa0': (89289910.0, 215000000.0), 'Man of Steel\xa0': (291021565.0, 225000000.0), 'The Chronicles of Narnia: Prince Caspian\xa0': (141614023.0, 225000000.0), 'The Avengers\xa0': (623279547.0, 220000000.0), 'Pirates of the Caribbean: On Stranger Tides\xa0': (241063875.0, 250000000.0), 'Men in Black 3\xa0': (179020854.0, 225000000.0), 'The Hobbit: The Battle of the Five Armies\xa0': (255108370.0, 250000000.0), 'The Amazing Spider-Man\xa0': (262030663.0, 230000000.0), 'Robin Hood\xa0': (105219735.0, 200000000.0), 'The Hobbit: The Desolation of Smaug\xa0': (258355354.0, 225000000.0), 'The Golden Compass\xa0': (70083519.0, 180000000.0), 'King Kong\xa0': (218051260.0, 207000000.0), 'Titanic\xa0': (658672302.0, 200000000.0), 'Captain America: Civil War\xa0': (407197282.0, 250000000.0), 'Battleship\xa0': (65173160.0, 209000000.0), 'Jurassic World\xa0': (652177271.0, 150000000.0), 'Skyfall\xa0': (304360277.0, 200000000.0), 'Spider-Man 2\xa0': (373377893.0, 200000000.0), 'Iron Man 3\xa0': (408992272.0, 200000000.0), 'Alice in Wonderland\xa0': (334185206.0, 200000000.0), 'X-Men: The Last Stand\xa0': (234360014.0, 210000000.0), 'Monsters University\xa0': (268488329.0, 200000000.0), 'Transformers: Revenge of the Fallen\xa0': (402076689.0, 200000000.0), 'Transformers: Age of Extinction\xa0': (245428137.0, 210000000.0), 'Oz the Great and Powerful\xa0': (234903076.0, 215000000.0), 'The Amazing Spider-Man 2\xa0': (202853933.0, 200000000.0), 'TRON: Legacy\xa0': (172051787.0, 170000000.0), 'Cars 2\xa0': (191450875.0, 200000000.0), 'Green Lantern\xa0': (116593191.0, 200000000.0), 'Toy Story 3\xa0': (414984497.0, 200000000.0), 'Terminator Salvation\xa0': (125320003.0, 200000000.0), 'Furious 7\xa0': (350034110.0, 190000000.0), 'World War Z\xa0': (202351611.0, 190000000.0), 'X-Men: Days of Future Past\xa0': (233914986.0, 200000000.0), 'Star Trek Into Darkness\xa0': (228756232.0, 190000000.0), 'Jack the Giant Slayer\xa0': (65171860.0, 195000000.0), 'The Great Gatsby\xa0': (144812796.0, 105000000.0), 'Prince of Persia: The Sands of Time\xa0': (90755643.0, 200000000.0), 'Pacific Rim\xa0': (101785482.0, 190000000.0), 'Transformers: Dark of the Moon\xa0': (352358779.0, 195000000.0), 'Indiana Jones and the Kingdom of the Crystal Skull\xa0': (317011114.0, 185000000.0), 'Brave\xa0': (237282182.0, 185000000.0), 'Star Trek Beyond\xa0': (130468626.0, 185000000.0), 'WALL·E\xa0': (223806889.0, 180000000.0), 'Rush Hour 3\xa0': (140080850.0, 140000000.0), '2012': (166112167.0, 200000000.0), 'A Christmas Carol\xa0': (137850096.0, 200000000.0), 'Jupiter Ascending\xa0': (47375327.0, 176000000.0), 'The Legend of Tarzan\xa0': (124051759.0, 180000000.0), 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe\xa0': (291709845.0, 180000000.0), 'X-Men: Apocalypse\xa0': (154985087.0, 178000000.0), 'The Dark Knight\xa0': (533316061.0, 185000000.0), 'Up\xa0': (292979556.0, 175000000.0), 'Monsters vs. Aliens\xa0': (198332128.0, 175000000.0), 'Iron Man\xa0': (318298180.0, 140000000.0), 'Hugo\xa0': (73820094.0, 170000000.0), 'Wild Wild West\xa0': (113745408.0, 170000000.0), 'The Mummy: Tomb of the Dragon Emperor\xa0': (102176165.0, 145000000.0), 'Suicide Squad\xa0': (161087183.0, 175000000.0), 'Evan Almighty\xa0': (100289690.0 ...
